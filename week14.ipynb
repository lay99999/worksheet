# %%
#1
class TreeNode:
    def __init__(self, key):
        self.left = None
        self.right = None
        self.val = key

def inorder_traversal(root):
    if root:
        inorder_traversal(root.left)
        print(root.val, end=" ")
        inorder_traversal(root.right)

def preorder_traversal(root):
    if root:
        print(root.val, end=" ")
        preorder_traversal(root.left)
        preorder_traversal(root.right)

def postorder_traversal(root):
    if root:
        postorder_traversal(root.left)
        postorder_traversal(root.right)
        print(root.val, end=" ")

root = TreeNode(84)
root.left = TreeNode(41)
root.right = TreeNode(96)
root.left.left = TreeNode(24)
root.left.right = TreeNode(50)

print("In-order traversal:")
inorder_traversal(root)
print("\nPre-order traversal:")
preorder_traversal(root)
print("\nPost-order traversal:")
postorder_traversal(root)
# Out:
# In-order traversal:
# 24 41 50 84 96
# Pre-order traversal:
# 84 41 24 50 96
# Post-order traversal:
# 24 50 41 96 84

# %%
#2
class TreeNode:
    def __init__(self, key):
        self.left = None
        self.right = None
        self.val = key

def build_tree():
    nodes = {}

    values = input("Enter integer values separated by spaces: ").split()

    for value in values:
        nodes[int(value)] = TreeNode(int(value))

    for value, node in nodes.items():
        print(f"Define the left and right children of {value}:")
        left_child_value = input("User (left): ")
        right_child_value = input("User (right): ")

        if left_child_value.isdigit():
            node.left = nodes[int(left_child_value)]
        if right_child_value.isdigit():
            node.right = nodes[int(right_child_value)]

        print("---------------------------------")
    return nodes[int(values[0])]

def inorder_traversal(root):
    if root:
        inorder_traversal(root.left)
        print(root.val, end=" ")
        inorder_traversal(root.right)
oot = build_tree()
print("In-order traversal (DFS):")
inorder_traversal(root)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 41
#      38         inorder_traversal(root.right)
#      40 # Build the tree
# ---> 41 root = build_tree()
#      43 # Perform in-order traversal (DFS)
#      44 print("In-order traversal (DFS):")
#
# Cell In[3], line 12, in build_tree()
#       9 nodes = {}
#      11 # Input integer values from the user
# ---> 12 values = input("Enter integer values separated by spaces: ").split()
#      14 # Create tree nodes for each value
#      15 for value in values:
#
# File ~/anaconda3/lib/python3.11/site-packages/ipykernel/kernelbase.py:1202, in Kernel.raw_input(self, prompt)
#    1200     msg = "raw_input was called, but this frontend does not support input requests."
#    1201     raise StdinNotImplementedError(msg)
# -> 1202 return self._input_request(
#    1203     str(prompt),
# ...

# %%
#2-1
class TreeNode:
    def __init__(self, key):
        self.left = None
        self.right = None
        self.val = key

def inorder_traversal(root):
    if root:
        inorder_traversal(root.left)
        print(root.val, end=" ")
        inorder_traversal(root.right)

def preorder_traversal(root):
    if root:
        print(root.val, end=" ")
        preorder_traversal(root.left)
        preorder_traversal(root.right)

def postorder_traversal(root):
    if root:
        postorder_traversal(root.left)
        postorder_traversal(root.right)
        print(root.val, end=" ")

root = TreeNode(3)
root.left = TreeNode(4)
root.right = TreeNode(0)
root.right.left = TreeNode(9)
root.right.right = TreeNode(7)
print("In-order traversal:")
inorder_traversal(root)
print("\nPre-order traversal:")
preorder_traversal(root)
print("\nPost-order traversal:")
postorder_traversal(root)
# Out:
# In-order traversal:
# 4 3 9 0 7
# Pre-order traversal:
# 3 4 0 9 7
# Post-order traversal:
# 4 9 7 0 3

# %%
#2-2
class TreeNode:
    def __init__(self, key):
        self.left = None
        self.right = None
        self.val = key

def inorder_traversal(root):
    if root:
        inorder_traversal(root.left)
        print(root.val, end=" ")
        inorder_traversal(root.right)

def preorder_traversal(root):
    if root:
        print(root.val, end=" ")
        preorder_traversal(root.left)
        preorder_traversal(root.right)

def postorder_traversal(root):
    if root:
        postorder_traversal(root.left)
        postorder_traversal(root.right)
        print(root.val, end=" ")

# Create the tree
root = TreeNode(4)
root.left = TreeNode(2)
root.right = TreeNode(7)
root.left.left = TreeNode(1)
root.left.right = TreeNode(3)

# Perform traversals
print("In-order traversal:")
inorder_traversal(root)
print("\nPre-order traversal:")
preorder_traversal(root)
print("\nPost-order traversal:")
postorder_traversal(root)

# %%
#2-3
class TreeNode:
    def __init__(self, key):
        self.left = None
        self.right = None
        self.val = key

def is_mirror(left, right):
    if not left and not right:
        return True
    if not left or not right:
        return False
    if left.val != right.val:
        return False
    return is_mirror(left.left, right.right) and is_mirror(left.right, right.left)

def is_symmetric(root):
    if not root:
        return True
    return is_mirror(root.left, root.right)

# Example usage:
root = TreeNode(1)
root.left = TreeNode(2)
root.right = TreeNode(2)
root.left.left = TreeNode(3)
root.left.right = TreeNode(4)
root.right.left = TreeNode(4)
root.right.right = TreeNode(3)

print(is_symmetric(root))  # Output: True

# %%
#2-4
class TreeNode:
    def __init__(self, key):
        self.left = None
        self.right = None
        self.val = key

def sum_of_left_leaves(root):
    def dfs(node, is_left):
        if not node:
            return 0
        if not node.left and not node.right and is_left:
            return node.val
        return dfs(node.left, True) + dfs(node.right, False)

    return dfs(root, False)
root = TreeNode(3)
root.left = TreeNode(9)
root.right = TreeNode(20)
root.right.left = TreeNode(15)
root.right.right = TreeNode(7)

print(sum_of_left_leaves(root))  # Output: 24
